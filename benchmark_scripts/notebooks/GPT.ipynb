# %% [markdown]
# # GPT GENERATED cases

# %%
import random
import math
import numpy as np
import time

from shapely.geometry import Polygon, box
from shapely.affinity import scale, translate
from shapely import wkt
from shapely.ops import transform
from pyproj import Transformer

import folium
from folium.features import DivIcon
from IPython.display import display, clear_output

# %% [markdown]
# ## Helper Function

# %%
def displayOSM(i, polygon, bbox, area_percentage=None):
    # Create a map with the center based on the bounding box
    map_center = [(bbox[1] + bbox[3]) / 2, (bbox[0] + bbox[2]) / 2]
    m = folium.Map(location=map_center, zoom_start=10) # SWEDEN ZOOM 4
    
    if isinstance(polygon, str):
        # Assuming the string is WKT format
        try:
            shape = wkt.loads(polygon)
            geo_json = shape.__geo_interface__
        except Exception as e:
            print(f"Error parsing polygon {e}")
    else:
        # Assuming it's already in a format folium can use
        geo_json = polygon
        
        # Add the polygon to the map with a unique style
    folium.GeoJson(
        geo_json,
        style_function=lambda x, color=f'#4400ff': {
                'fillColor': color,
                'color': 'black',
                'weight': 2,
                'dashArray': '5, 5',
                'fillOpacity': 0.5,
        }
    ).add_to(m)

    north, south, east, west = bbox[3], bbox[1], bbox[0], bbox[2]
    # Add the bounding box to the map
    folium.Rectangle(bounds=[[north, west], [south, east]], color="red", fill=False).add_to(m)

    folium.map.Marker(
        [north-0.25, east],
        icon=DivIcon(
            icon_size=(350,56),
            icon_anchor=(0,0),
            html='<div style="font-size: 18pt; color: #4400ff;">points '+str(i)+' | area '+str(area_percentage*100.0)+'% BBOX</div>',
            )
        ).add_to(m)
    display(m)
    clear_output(wait=True)
    time.sleep(0.5)  # Pause to see the update
    # return m

# %%
def get_bbox_polygon(bbox):
    minx, miny, maxx, maxy = bbox
    return box(minx, miny, maxx, maxy)

def create_regular_polygon(center_x, center_y, radius, num_points):
    """Generates a regular convex polygon"""
    return Polygon([
        (
            center_x + radius * math.cos(2 * math.pi * i / num_points),
            center_y + radius * math.sin(2 * math.pi * i / num_points)
        )
        for i in range(num_points)
    ])

def scale_to_bbox_area(geom, target_area):
    """Scales a geometry to match a target area"""
    current_area = geom.area
    scale_factor = math.sqrt(target_area / current_area)
    return scale(geom, xfact=scale_factor, yfact=scale_factor, origin='center')

def add_holes_to_polygon(poly, num_holes):
    """Adds holes inside a polygon by subtracting smaller shapes"""
    if not poly.is_valid or poly.is_empty:
        return poly
    minx, miny, maxx, maxy = poly.bounds
    holes = []
    for i in range(num_holes):
        hole_width = (maxx - minx) * 0.1
        hole_height = (maxy - miny) * 0.1
        hole_x = random.uniform(minx + hole_width, maxx - hole_width)
        hole_y = random.uniform(miny + hole_height, maxy - hole_height)
        hole = box(hole_x, hole_y, hole_x + hole_width, hole_y + hole_height)
        if poly.contains(hole):
            holes.append(hole.exterior.coords)
    return Polygon(shell=poly.exterior.coords, holes=holes)

# GENERATOR SUB FUNCTIONS

def genCase1(bbox, num_points, percentage_of_area=0.5):
    """Simple polygon with fixed area (50% of BBOX)"""
    bbox_poly = get_bbox_polygon(bbox)
    cx, cy = bbox_poly.centroid.x, bbox_poly.centroid.y
    radius = min(bbox_poly.bounds[2] - bbox_poly.bounds[0],
                 bbox_poly.bounds[3] - bbox_poly.bounds[1]) / 4
    poly = create_regular_polygon(cx, cy, radius, num_points)
    poly_scaled = scale_to_bbox_area(poly, bbox_poly.area * percentage_of_area)
    return poly_scaled.wkt

def genCase2(bbox, num_points=4, percentage_of_area=1.0):
    """Simple polygon with varying area (1%-100%)"""
    return genCase1(bbox, num_points, percentage_of_area)

def genCase3(bbox, holes=1):
    """Polygon with one hole"""
    bbox_poly = get_bbox_polygon(bbox)
    outer = scale(bbox_poly, 0.9, 0.9, origin='center')
    return add_holes_to_polygon(outer, holes).wkt

def genCase6(bbox, holes):
    """Polygon with multiple holes"""
    bbox_poly = get_bbox_polygon(bbox)
    outer = scale(bbox_poly, 0.9, 0.9, origin='center')
    return add_holes_to_polygon(outer, holes).wkt

def genCaseLineLike(bbox):
    """Polygon with very narrow width (line-like shape)"""
    minx, miny, maxx, maxy = bbox
    height = (maxy - miny) * 0.01
    return box(minx, miny, maxx, miny + height).wkt

# %% [markdown]
# ## USER GLOBAL VARIABLES

# %%
INPUT_BBOX = [11.360694444453532, 48.06152777781623, 11.723194444453823, 48.24819444448305]
NUM_OF_POINTS = 10
NUM_OF_HOLES = 10
PERCENTAGE_OF_AREA = 0.5  # 50% area of INPUT_BBOX

# %% [markdown]
# ## Cases

# %%
poly = genCase1(INPUT_BBOX, NUM_OF_POINTS, PERCENTAGE_OF_AREA)
print(f"LINEAR POLYGON \n\n{poly}\n")
displayOSM(NUM_OF_POINTS, poly, INPUT_BBOX, PERCENTAGE_OF_AREA)
# Out:
# LINEAR POLYGON
#
# POLYGON ((11.649239089891907 48.15486111114964, 11.628747636018641 48.21792732138819, 11.575100313299522 48.25690438285726, 11.508788575607827 48.25690438285726, 11.455141252888708 48.21792732138819, 11.434649799015443 48.15486111114964, 11.455141252888708 48.0917949009111, 11.508788575607827 48.05281783944204, 11.575100313299522 48.05281783944204, 11.628747636018641 48.0917949009111, 11.649239089891907 48.15486111114964))
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b8785260b15dfcc81d9c5010d3bb7397 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b8785260b15dfcc81d9c5010d3bb7397&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b8785260b15dfcc81d9c5010d3bb7397 = L.map(
#                 &quot;map_b8785260b15dfcc81d9c5010d3bb7397&quot;,
#                 {
#                     center: [48.15486111114964, 11.541944444453677],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_254acf498c1e365e2f796ba7f4e57d9b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_254acf498c1e365e2f796ba7f4e57d9b.addTo(map_b8785260b15dfcc81d9c5010d3bb7397);
#
#
#         function geo_json_251c644301fac6181323e1919b9f3e99_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#4400ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_251c644301fac6181323e1919b9f3e99_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_251c644301fac6181323e1919b9f3e99 = L.geoJson(null, {
#                 onEachFeature: geo_json_251c644301fac6181323e1919b9f3e99_onEachFeature,
#
#                 style: geo_json_251c644301fac6181323e1919b9f3e99_styler,
#             ...{
# }
#         });
#
#         function geo_json_251c644301fac6181323e1919b9f3e99_add (data) {
#             geo_json_251c644301fac6181323e1919b9f3e99
#                 .addData(data);
#         }
#             geo_json_251c644301fac6181323e1919b9f3e99_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[11.649239089891907, 48.15486111114964], [11.628747636018641, 48.21792732138819], [11.575100313299522, 48.25690438285726], [11.508788575607827, 48.25690438285726], [11.455141252888708, 48.21792732138819], [11.434649799015443, 48.15486111114964], [11.455141252888708, 48.0917949009111], [11.508788575607827, 48.05281783944204], [11.575100313299522, 48.05281783944204], [11.628747636018641, 48.0917949009111], [11.649239089891907, 48.15486111114964]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_251c644301fac6181323e1919b9f3e99.addTo(map_b8785260b15dfcc81d9c5010d3bb7397);
#
#
#             var rectangle_3c81490646e5c49d17e279fd4aa379ba = L.rectangle(
#                 [[48.24819444448305, 11.723194444453823], [48.06152777781623, 11.360694444453532]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b8785260b15dfcc81d9c5010d3bb7397);
#
#
#             var marker_6c4a8cc991be5703b025122c9355e116 = L.marker(
#                 [47.99819444448305, 11.360694444453532],
#                 {
# }
#             ).addTo(map_b8785260b15dfcc81d9c5010d3bb7397);
#
#
#             var div_icon_3a84103c2fd073fd89a51c6f414fee40 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 18pt; color: #4400ff;\&quot;\u003epoints 10 | area 50.0% BBOX\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [350, 56],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_6c4a8cc991be5703b025122c9355e116.setIcon(div_icon_3a84103c2fd073fd89a51c6f414fee40);
#
#
#                 marker_6c4a8cc991be5703b025122c9355e116.setIcon(div_icon_3a84103c2fd073fd89a51c6f414fee40);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
poly = genCase2(INPUT_BBOX, NUM_OF_POINTS, PERCENTAGE_OF_AREA)
print(f"LINEAR POLYGON \n\n{poly}\n")
displayOSM(NUM_OF_POINTS, poly, INPUT_BBOX, PERCENTAGE_OF_AREA)
# Out:
# LINEAR POLYGON
#
# POLYGON ((11.649239089891907 48.15486111114964, 11.628747636018641 48.21792732138819, 11.575100313299522 48.25690438285726, 11.508788575607827 48.25690438285726, 11.455141252888708 48.21792732138819, 11.434649799015443 48.15486111114964, 11.455141252888708 48.0917949009111, 11.508788575607827 48.05281783944204, 11.575100313299522 48.05281783944204, 11.628747636018641 48.0917949009111, 11.649239089891907 48.15486111114964))
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_617fdca18894e6fe55e0c22ff8a41ef9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_617fdca18894e6fe55e0c22ff8a41ef9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_617fdca18894e6fe55e0c22ff8a41ef9 = L.map(
#                 &quot;map_617fdca18894e6fe55e0c22ff8a41ef9&quot;,
#                 {
#                     center: [48.15486111114964, 11.541944444453677],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9df3ca22ee9b7fe6312349f1e8670ceb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9df3ca22ee9b7fe6312349f1e8670ceb.addTo(map_617fdca18894e6fe55e0c22ff8a41ef9);
#
#
#         function geo_json_8fd98f237d12bbe1fffbc279725fc286_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#4400ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_8fd98f237d12bbe1fffbc279725fc286_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_8fd98f237d12bbe1fffbc279725fc286 = L.geoJson(null, {
#                 onEachFeature: geo_json_8fd98f237d12bbe1fffbc279725fc286_onEachFeature,
#
#                 style: geo_json_8fd98f237d12bbe1fffbc279725fc286_styler,
#             ...{
# }
#         });
#
#         function geo_json_8fd98f237d12bbe1fffbc279725fc286_add (data) {
#             geo_json_8fd98f237d12bbe1fffbc279725fc286
#                 .addData(data);
#         }
#             geo_json_8fd98f237d12bbe1fffbc279725fc286_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[11.649239089891907, 48.15486111114964], [11.628747636018641, 48.21792732138819], [11.575100313299522, 48.25690438285726], [11.508788575607827, 48.25690438285726], [11.455141252888708, 48.21792732138819], [11.434649799015443, 48.15486111114964], [11.455141252888708, 48.0917949009111], [11.508788575607827, 48.05281783944204], [11.575100313299522, 48.05281783944204], [11.628747636018641, 48.0917949009111], [11.649239089891907, 48.15486111114964]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_8fd98f237d12bbe1fffbc279725fc286.addTo(map_617fdca18894e6fe55e0c22ff8a41ef9);
#
#
#             var rectangle_798cd7cdc88969950b7ae5227701b6f1 = L.rectangle(
#                 [[48.24819444448305, 11.723194444453823], [48.06152777781623, 11.360694444453532]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_617fdca18894e6fe55e0c22ff8a41ef9);
#
#
#             var marker_360699be69584b92f7e1bcbde900ae2b = L.marker(
#                 [47.99819444448305, 11.360694444453532],
#                 {
# }
#             ).addTo(map_617fdca18894e6fe55e0c22ff8a41ef9);
#
#
#             var div_icon_a15dc62c5f0f5396b105dde6356d751f = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 18pt; color: #4400ff;\&quot;\u003epoints 10 | area 50.0% BBOX\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [350, 56],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_360699be69584b92f7e1bcbde900ae2b.setIcon(div_icon_a15dc62c5f0f5396b105dde6356d751f);
#
#
#                 marker_360699be69584b92f7e1bcbde900ae2b.setIcon(div_icon_a15dc62c5f0f5396b105dde6356d751f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
poly = genCase3(INPUT_BBOX, holes=1)
print(f"LINEAR POLYGON \n\n{poly}\n")
displayOSM(NUM_OF_POINTS, poly, INPUT_BBOX, PERCENTAGE_OF_AREA)
# Out:
# LINEAR POLYGON
#
# POLYGON ((11.705069444453809 48.070861111149576, 11.705069444453809 48.23886111114971, 11.378819444453548 48.23886111114971, 11.378819444453548 48.070861111149576, 11.705069444453809 48.070861111149576), (11.508601947462504 48.10870908343727, 11.508601947462504 48.12550908343728, 11.475976947462478 48.12550908343728, 11.475976947462478 48.10870908343727, 11.508601947462504 48.10870908343727))
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9c5e857d66290404d466180dff827481 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9c5e857d66290404d466180dff827481&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9c5e857d66290404d466180dff827481 = L.map(
#                 &quot;map_9c5e857d66290404d466180dff827481&quot;,
#                 {
#                     center: [48.15486111114964, 11.541944444453677],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3d8db52955a8c82cfec9453d68133f03 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3d8db52955a8c82cfec9453d68133f03.addTo(map_9c5e857d66290404d466180dff827481);
#
#
#         function geo_json_29eea82513ef25a66f40eafc34a7062e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#4400ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_29eea82513ef25a66f40eafc34a7062e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_29eea82513ef25a66f40eafc34a7062e = L.geoJson(null, {
#                 onEachFeature: geo_json_29eea82513ef25a66f40eafc34a7062e_onEachFeature,
#
#                 style: geo_json_29eea82513ef25a66f40eafc34a7062e_styler,
#             ...{
# }
#         });
#
#         function geo_json_29eea82513ef25a66f40eafc34a7062e_add (data) {
#             geo_json_29eea82513ef25a66f40eafc34a7062e
#                 .addData(data);
#         }
#             geo_json_29eea82513ef25a66f40eafc34a7062e_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[11
]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_febc63c64825a7a5b89afa92577abfb4.addTo(map_c2c0028a0ce127ce82353075998fba98);
#
#
#             var rectangle_8c596feec514605c30815f378ffdaee3 = L.rectangle(
#                 [[48.24819444448305, 11.723194444453823], [48.06152777781623, 11.360694444453532]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quo

# %%
poly = genCaseLineLike(INPUT_BBOX)
print(f"LINEAR POLYGON \n\n{poly}\n")
displayOSM(NUM_OF_POINTS, poly, INPUT_BBOX, PERCENTAGE_OF_AREA)
# Out:
# LINEAR POLYGON
#
# POLYGON ((11.723194444453823 48.06152777781623, 11.723194444453823 48.063394444482896, 11.360694444453532 48.063394444482896, 11.360694444453532 48.06152777781623, 11.723194444453823 48.06152777781623))
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ec0ef577b31cba6a565e497991c80e52 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ec0ef577b31cba6a565e497991c80e52&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ec0ef577b31cba6a565e497991c80e52 = L.map(
#                 &quot;map_ec0ef577b31cba6a565e497991c80e52&quot;,
#                 {
#                     center: [48.15486111114964, 11.541944444453677],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0a470e19f3558c8bf1350ceae6a67408 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0a470e19f3558c8bf1350ceae6a67408.addTo(map_ec0ef577b31cba6a565e497991c80e52);
#
#
#         function geo_json_043830df809618e13d44331a84362913_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5, 5&quot;, &quot;fillColor&quot;: &quot;#4400ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_043830df809618e13d44331a84362913_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_043830df809618e13d44331a84362913 = L.geoJson(null, {
#                 onEachFeature: geo_json_043830df809618e13d44331a84362913_onEachFeature,
#
#                 style: geo_json_043830df809618e13d44331a84362913_styler,
#             ...{
# }
#         });
#
#         function geo_json_043830df809618e13d44331a84362913_add (data) {
#             geo_json_043830df809618e13d44331a84362913
#                 .addData(data);
#         }
#             geo_json_043830df809618e13d44331a84362913_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[11.723194444453823, 48.06152777781623], [11.723194444453823, 48.063394444482896], [11.360694444453532, 48.063394444482896], [11.360694444453532, 48.06152777781623], [11.723194444453823, 48.06152777781623]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_043830df809618e13d44331a84362913.addTo(map_ec0ef577b31cba6a565e497991c80e52);
#
#
#             var rectangle_c102ade301b4bdc5feed86f246f4bfc3 = L.rectangle(
#                 [[48.24819444448305, 11.723194444453823], [48.06152777781623, 11.360694444453532]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ec0ef577b31cba6a565e497991c80e52);
#
#
#             var marker_890d052b33825007aaf043b451d10673 = L.marker(
#                 [47.99819444448305, 11.360694444453532],
#                 {
# }
#             ).addTo(map_ec0ef577b31cba6a565e497991c80e52);
#
#
#             var div_icon_0d6c838ee39a91586d2ef49df6bcb23f = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 18pt; color: #4400ff;\&quot;\u003epoints 10 | area 50.0% BBOX\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [350, 56],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_890d052b33825007aaf043b451d10673.setIcon(div_icon_0d6c838ee39a91586d2ef49df6bcb23f);
#
#
#                 marker_890d052b33825007aaf043b451d10673.setIcon(div_icon_0d6c838ee39a91586d2ef49df6bcb23f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
